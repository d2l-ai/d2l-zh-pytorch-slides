# %% [markdown]
# # 数值稳定性和模型初始化
#
# 梯度消失

# %%
# %matplotlib inline
import torch
from d2l import torch as d2l

x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.sigmoid(x)
y.backward(torch.ones_like(x))

d2l.plot(x.detach().numpy(), [y.detach().numpy(), x.grad.numpy()],
         legend=['sigmoid', 'gradient'], figsize=(4.5, 2.5))

# %% [markdown]
# 梯度爆炸

# %%
M = torch.normal(0, 1, size=(4,4))
print('一个矩阵 \n',M)
for i in range(100):
    M = torch.mm(M,torch.normal(0, 1, size=(4, 4)))

print('乘以100个矩阵后\n', M)
# Out:
# 一个矩阵
#  tensor([[-1.4825,  0.7353,  1.7364,  1.5502],
#         [-0.6260, -0.3832,  1.4020, -0.8366],
#         [-0.3678,  0.6168, -0.8579, -0.5523],
#         [-1.1685, -0.0843,  0.2277, -1.3600]])
# 乘以100个矩阵后
#  tensor([[-8.9657e+23, -6.5938e+23,  1.3063e+23,  5.8993e+23],
#         [ 2.5795e+24,  1.8971e+24, -3.7583e+23, -1.6973e+24],
#         [-4.2085e+23, -3.0951e+23,  6.1316e+22,  2.7691e+23],
#         [ 3.0246e+24,  2.2244e+24, -4.4067e+23, -1.9901e+24]])
